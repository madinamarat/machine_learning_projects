# %%
import pandas as pd

fert = pd.read_csv('./data/gapminder_total_fertility.csv', index_col=0)

# %%
fert.head(2)
# Out:
#                       1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.0   7.0   7.0   7.0   7.0   7.0   7.0   7.0   7.0
#
#                       1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate        ...
# Abkhazia               NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.0  ...   6.7  6.46   6.2  5.93  5.66   5.4  5.14
#
#                       2013  2014  2015
# Total fertility rate
# Abkhazia               NaN   NaN   NaN
# Afghanistan            4.9  4.68  4.47
#
# [2 rows x 216 columns]

# %%
life = pd.read_excel('./data/gapminder_lifeexpectancy.xlsx', index_col=0)

# %%
life.head(2)
# Out:
#                   1800  1801   1802   1803   1804   1805   1806   1807   1808  \
# Life expectancy
# Abkhazia           NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan      28.21  28.2  28.19  28.18  28.17  28.16  28.15  28.14  28.13
#
#                   1809  ...  2007  2008  2009  2010  2011  2012  2013  2014  \
# Life expectancy         ...
# Abkhazia           NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan      28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9
#
#                  2015   2016
# Life expectancy
# Abkhazia          NaN    NaN
# Afghanistan      53.8  52.72
#
# [2 rows x 217 columns]

# %%
print(life.shape)
# Out:
# (260, 217)

# %%
print(fert.shape)
# Out:
# (260, 216)

# %%
fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
life.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
ncol = [int(x) for x in fert.columns]
fert.set_axis(axis=1, labels=ncol, inplace=True)

# %%
sfert = fert.stack()

# %%
slife = life.stack()

# %%
d = {'fertility': sfert, 'lifeexp': slife}
df2 = pd.DataFrame(data=d)

# %%
df2
# Out:
#                   fertility  lifeexp
# Afghanistan 1800        7.0    28.21
#             1801        7.0    28.20
#             1802        7.0    28.19
#             1803        7.0    28.18
#             1804        7.0    28.17
# ...                     ...      ...
# Åland       2002        NaN    81.80
#             2003        NaN    80.63
#             2004        NaN    79.88
#             2005        NaN    80.00
#             2006        NaN    80.10
#
# [44007 rows x 2 columns]

# %%
popul = pd.read_excel('./data/gapminder_population.xlsx', index_col=0)

# %%
print(popul.shape)
# Out:
# (275, 81)

# %%
popul.columns
# Out:
# Int64Index([1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900,
#             1910, 1920, 1930, 1940, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#             1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#             1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#             1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#             1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015],
#            dtype='int64')

# %%
spopul=popul.stack()

# %%
spopul
# Out:
# Total population
# Afghanistan                1800    3280000.0
#                            1810    3280000.0
#                            1820    3323519.0
#                            1830    3448982.0
#                            1840    3625022.0
#                                      ...
# Sint Maarten (Dutch part)  2011      33979.0
#                            2012      35134.0
#                            2013      36442.0
#                            2014      37696.0
#                            2015      38745.0
# Length: 20176, dtype: float64

# %%
d = {'fertility': sfert, 'lifeexp': slife, 'population': spopul}
df2 = pd.DataFrame(data=d)
df2
# Out:
#                   fertility  lifeexp  population
# Afghanistan 1800        7.0    28.21   3280000.0
#             1801        7.0    28.20         NaN
#             1802        7.0    28.19         NaN
#             1803        7.0    28.18         NaN
#             1804        7.0    28.17         NaN
# ...                     ...      ...         ...
# Åland       2006        NaN    80.10     26923.0
#             2007        NaN      NaN     26923.0
#             2008        NaN      NaN     26923.0
#             2009        NaN      NaN     26923.0
#             2010        NaN      NaN     26923.0
#
# [47688 rows x 3 columns]

# %%
df3 = df2.stack()
df3
# Out:
# Afghanistan  1800  fertility           7.00
#                    lifeexp            28.21
#                    population    3280000.00
#              1801  fertility           7.00
#                    lifeexp            28.20
#                                     ...
# Åland        2006  population      26923.00
#              2007  population      26923.00
#              2008  population      26923.00
#              2009  population      26923.00
#              2010  population      26923.00
# Length: 107445, dtype: float64

# %%
df4 = df3.unstack((0,2))
df4
# Out:
#      Afghanistan                     Akrotiri and Dhekelia   Albania          \
#        fertility lifeexp  population            population fertility lifeexp
# 1800        7.00   28.21   3280000.0                   NaN      4.60    35.4
# 1801        7.00   28.20         NaN                   NaN      4.60    35.4
# 1802        7.00   28.19         NaN                   NaN      4.60    35.4
# 1803        7.00   28.18         NaN                   NaN      4.60    35.4
# 1804        7.00   28.17         NaN                   NaN      4.60    35.4
# ...          ...     ...         ...                   ...       ...     ...
# 2012        5.14   54.40  29726803.0                   NaN      1.76    77.5
# 2013        4.90   54.80  30682500.0                   NaN      1.77    77.7
# 2014        4.68   54.90  31627506.0                   NaN      1.78    77.9
# 2015        4.47   53.80  32526562.0                   NaN      1.78    78.0
# ...

# %%
import pylab as plt
df4[['Germany', 'France', 'Sweden']].plot()

# %%
df5 = df3.unstack(2)
df5.plot.scatter('fertility', 'lifeexp', s=0.1)

# %%
df6 = df3.unstack(1)
df6 = df6[1950]
df6 = df6.unstack(1)
df6.plot.scatter('fertility', 'lifeexp', s=3)

# %%
cmap = plt.get_cmap('tab20', lut = len(df6)).colors
df6.plot.scatter('fertility', 'lifeexp', s=10, c=cmap)

# %%
cmap = plt.get_cmap("tab20", lut = len(df6)).colors
df6.plot.scatter('fertility', 'lifeexp', s=df6['population']/150000, c=cmap)

# %%
y = 1960

for i in range(1960,2016):
    df6 = df3.unstack(1)
    df6 = df6[y]
    df6 = df6.unstack(1)
    df6.plot.scatter('fertility', 'lifeexp', s=df6['population']/100000, c=cmap)
    plt.axis((0, 10, 0, 120))
    plt.title(y)
    # get rid of the frame
    for spine in plt.gca().spines.values():
        spine.set_visible(False)
    plt.savefig(f"lifeexp_{y}.png")
    y = y+1
# Out:
# /Users/madinamukhambekova/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
pip install imageio
# Out:
# ...
# WARNING: You are using pip version 20.2.4; however, version 20.3.1 is available.
# You should consider upgrading via the '/Users/madinamukhambekova/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import imageio
images = []
for i in range(1960, 2016):
    filename = 'lifeexp_{}.png'.format(i)
    images.append(imageio.imread(filename))

imageio.mimsave('./data/output.gif', images, fps=20)

# %%
from IPython.display import Image
Image(filename='./data/output.gif')
